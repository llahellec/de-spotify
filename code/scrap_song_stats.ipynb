# %%
https://github.com/TheFrenchGhosty/TheFrenchGhostys-Ultimate-YouTube-DL-Scripts-Collection

# --- resumable loop settings ---
SAVE_EVERY_N = 25          # periodic safe save
BASE_SLEEP_SECONDS = 3.0   # polite throttle; increase if you see blocking
MAX_ROWS_THIS_RUN = None   # set an int to limit a session, e.g. 200

processed = 0
updated = 0
start_time = time.time()
import pandas as pd
import requests
import re
import time
from datetime import datetime
%%

def looks_blocked(text: str) -> bool:
    t = (text or "").lower()
    # heuristic only (site-specific wording varies)
    keywords = [
        "captcha", "verify you are", "unusual traffic", "access denied",
        "cloudflare", "attention required", "blocked", "too many requests"
    ]
    return any(k in t for k in keywords)

def fetch_songstats_html(isrc: str, timeout=20):
    url = f"https://songstats.com/{isrc}?ref=ISRCFinder"
    r = session.get(url, timeout=timeout)
    return r, url

# %%
# %%
#
# %%
